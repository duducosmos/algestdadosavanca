# %%
from IPython.display import HTML
from IPython.display import Image

# %% [markdown]
# # Filas de Prioridade
#
# 1. Estrutura de Dados do tipo pilha e fila são consideradas listas especializadas.
# 2. Possuem operações como inserir elemento, excluir um elemento, encotrar o maior, encontra o menor, alterar um elemento, buscá-lo, buscar o sucessor e buscar o predecessor
# 3. Representam conjunto de dados que estão organizados em ordem linear

# %% [markdown]
# 1. Filas e pilhas estáticas: Quando se utiliza vetoras nas representaçõe, tem o uso contíguo de memória do computador e a ordem linear é determinada pelos índices do vetor.
# 2. Filas e pilhas dinâmicas: suas estruturas são representadas por elementos que, além de conter o dado, possuem também um ponteiro para o próximo elemento (elementos encadeados).
# 3. Pilhas e Filas homogêneas: contém apenas dados primitivos.
# 4. Pilhas e Filas heterogêneas: contém dados compostos.

# %%
Image(filename='./imagens/pilha.png')

# %%
Image(filename='./imagens/fila.png')

# %% [markdown]
# ## Pilha
#
# 1. Considerada FILO (First In Last Out) - O primeiro elemento inserido será o último a ser removido.
# 2. Cada elemento armazena um ou vários dados e um ponteiro para o próximo elemento, permitindo o encadeamento e mantendo a estrutura linear.
# 3. Possui um ponteiro chamado TOPO, no qual todas as operações de inserção e remoção acontecem.
# 4. As operações ocorrem sempre na mesma extremidade da estrutura.

# %%
Image(filename='./imagens/operacaopilha01.png')

# %%
Image(filename='./imagens/operacaopilha02.png')

# %% [markdown]
# ### Pilha em Python

# %%
class Pilha:
    num = None;
    prox = None
    def __del__(self):
        print("Objeto será deletado")
    
class Controle:
    
    def __init__(self):
        self.topo = None
        self.aux = None
    
    def menu(self):
        txt = """
        Opções:
        1 - Inserir na pilha
        2 - Consultar toda a pilha
        3 - Remover da pilha
        4 - Esvaziar a pilha
        5 - sair
        Digite a sua opção
        """

        opcao = int(input(txt))
        return opcao
    
    def main(self):
        opcoes = {1:self.opcao1, 2:self.opcao2, 3:self.opcao3, 4:self.opcao4}
        while True:
            opcao = self.menu()
            if opcao in opcoes:
                opcoes[opcao]()
            else:
                if opcao == 5:
                    break
                else:
                    print("Opção inválida")
                                
    def printpilhavazia(self):
        print("A pilha está vazia")
                

    def opcao1(self):
        novo = Pilha()
        novo.num = int(input("Digite o número a ser inserido na pilha: "))
        novo.prox = self.topo
        self.topo = novo

    def opcao2(self):
        if self.topo is None:
            self.printpilhavazia()
        else:
            print("Consultando a pilha!")
            self.aux = self.topo
            while self.aux is not None:
                print(self.aux.num)
                self.aux = self.aux.prox

    def opcao3(self):
        if self.topo is None:
            self.printpilhavazia()
        else:
            print("A pilha contém elementos e o último elemento inserido será removido")
            self.topo = self.topo.prox
            
        

    def opcao4(self):
        if self.topo is None:
            self.printpilhavazia()
        else:
            print("A pilha será esvaziada")
            # Usar essa opção mantém lixo na memória
            # self.topo = None 
            
            self.aux = self.topo
            while self.aux is not None:
                self.topo = self.topo.prox
                del self.aux
                self.aux = self.topo
                
            print("Pilha esvaziada")

    
        
controle = Controle()
controle.main()
# Out:
# Objeto será deletado
#
#         Opções:
#         1 - Inserir na pilha
#         2 - Consultar toda a pilha
#         3 - Remover da pilha
#         4 - Esvaziar a pilha
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na pilha: 2
#
#         Opções:
#         1 - Inserir na pilha
#         2 - Consultar toda a pilha
#         3 - Remover da pilha
#         4 - Esvaziar a pilha
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na pilha: 5
#
#         Opções:
#         1 - Inserir na pilha
#         2 - Consultar toda a pilha
#         3 - Remover da pilha
#         4 - Esvaziar a pilha
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na pilha: 6
#
#         Opções:
#         1 - Inserir na pilha
#         2 - Consultar toda a pilha
#         3 - Remover da pilha
#         4 - Esvaziar a pilha
#         5 - sair
#         Digite a sua opção
#         2
# ...

# %% [markdown]
# ### Análise de complexidade
#
# 1. Operações de remoção e inserção na pilha sermpre realiza operações básicas, como a de atribuição, para atualizar o topo da pilha. Logo, são opreações de tempo constante e gatam tempo $O(1)$
# 2. As operações de consultar toda a pilha percorre todos os elementos armazenados.
# 3. Se a pilha tem $n$ elementos, o tempo de execução será $O(n)$
# 4. Limpara a pilha depende da linhguagem. Em Python e Java, ao colocar o ponteiro topo da pilha como nulo, o Garbage collector verificará, depois de um determinado tempo, que aqueles objetos não estão mais sendo referenciados por ninguem, o interpretador irá remover o dado. Porém, isso acaba gerando muita sugeira e consumindo memória de forma desnecessária.
# 5. Podemos garatir a remoção de item por item com o comando `del`. Nesse caso o tempo para remover todos os elementos, limpando a memória será de ordem $O(n)$

# %% [markdown]
# ## Fila
#
# 1. Tipo FIFO (First In First Out) - Primeiro elemento a ser inserido será o primeiro a ser removido.
# 2. Cada elemento armazena um ou vários dados e um ponteiro para o próximo elemento, permitindo o encadeamento e mantendo a estrutura linear.
# 3. A estrutura do tipo fila possui um ponteiro denominado INICIO, onde as remoções ocorrem nas duas extremidades da estrutura

# %%
Image(filename='./imagens/operacaofila01.png')

# %%
Image(filename='./imagens/operacaofila02.png')

# %%
class Fila:
    num = None;
    prox = None
    def __del__(self):
        print("Objeto será deletado")
    
class Controle:
    
    def __init__(self):
        self.inicio = None
        self.fim = None
        self.aux = None
    
    def menu(self):
        txt = """
        Opções:
        1 - Inserir na fila
        2 - Consultar toda a fila
        3 - Remover da fila
        4 - Esvaziar a fila
        5 - sair
        Digite a sua opção
        """

        opcao = int(input(txt))
        return opcao
    
    def main(self):
        opcoes = {1:self.opcao1, 2:self.opcao2, 3:self.opcao3, 4:self.opcao4}
        while True:
            opcao = self.menu()
            if opcao in opcoes:
                opcoes[opcao]()
            else:
                if opcao == 5:
                    break
                else:
                    print("Opção inválida")
                                
    def printpilhavazia(self):
        print("A fila está vazia")
                

    def opcao1(self):
        novo = Fila()
        novo.num = int(input("Digite o número a ser inserido na fila: "))
        novo.prox = None
        if self.inicio is None:
            self.inicio = novo
            self.fim = novo
        else:
            self.fim.prox = novo
            self.fim = novo

    def opcao2(self):
        if self.inicio is None:
            self.printpilhavazia()
        else:
            print("Consultando a fila!")
            self.aux = self.inicio
            while self.aux is not None:
                print(self.aux.num)
                self.aux = self.aux.prox

    def opcao3(self):
        if self.inicio is None:
            self.printpilhavazia()
        else:
            print("A fila contém elementos e o último elemento inserido será removido")
            self.inicio = self.inicio.prox           
        

    def opcao4(self):
        if self.inicio is None:
            self.printpilhavazia()
        else:
            print("A fila será esvaziada")
            # Usar essa opção mantém lixo na memória
            # self.topo = None 
            
            self.aux = self.inicio
            while self.aux is not None:
                self.inicio = self.inicio.prox
                del self.aux
                self.aux = self.inicio
                
            print("fila esvaziada")

    
        
controle = Controle()
controle.main()
# Out:
#         Opções:
#         1 - Inserir na fila
#         2 - Consultar toda a fila
#         3 - Remover da fila
#         4 - Esvaziar a fila
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na fila: 2
#
#         Opções:
#         1 - Inserir na fila
#         2 - Consultar toda a fila
#         3 - Remover da fila
#         4 - Esvaziar a fila
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na fila: 5
#
#         Opções:
#         1 - Inserir na fila
#         2 - Consultar toda a fila
#         3 - Remover da fila
#         4 - Esvaziar a fila
#         5 - sair
#         Digite a sua opção
#         1
# Digite o número a ser inserido na fila: 6
#
#         Opções:
#         1 - Inserir na fila
#         2 - Consultar toda a fila
#         3 - Remover da fila
#         4 - Esvaziar a fila
#         5 - sair
#         Digite a sua opção
#         2
# Consultando a fila!
# 2
# 5
# 6
#
# ...

# %% [markdown]
# Qual a complexidade do algoritmo de fila?

# %% [markdown]
# ## Exercícios
#
# 1. O que é o Garbage Collector?
# 2. Faça um programa que cadastre 5 números em uma fila dinâmica e mais 5 em uma pilha dinâmica. Em seguida, o programa deve mostrar três relatórios. O primeiro terá os núemros que estão nas duasd estruturas. O segundo terá os que estão apenas na fila e o terceiro os que estão apenas na pilha.
# 3. Faça um programa que apresente o meno de opções abaixo:
#     - 1. Cadastrar o número
#     - 2. Mostrar  números pares entre os primeiro e o último cadastrado
#     - 3. Excuir número
#     - 4. Sair.
#
#  Observações
#
#     1. O programa deve ser implementado usando uma estrutura do tipo pilha
#     2. A opção 1 do menu cadastra um número de cada vez
#     3. Mostrar mensagem para opção inválida do menu
#     4. Cuidado com o intervalo de números formado pelo primeiro e pelo último número da pilha, pois este pode ser crescente, decrescente ou ainda ser o mesmo número.
#     5. Quando a opção do menu não puder ser realizada, mostrar mensagem.
#
# 4. Faça um programa que apresente o menu de opções abaix:
#     -1. Cadastrar tipo
#     -2. Cadastrar produto
#     -3. Consultar o preço de um produto
#     -4. Excluir o preço de um produto
#     -5. Sair
